# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('/content/test_dirty_dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  125 non-null    int64
#  1   age          114 non-null    object
#  2   salary       117 non-null    float64
#  3   signup_date  125 non-null    object
#  4   active       125 non-null    object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 5.0+ KB

# %%
from neuro_symbolic_agent2 import run_neuro_symbolic_agent

# %%
data_context = {
    "null_ratio": df.isna().mean().mean(),
    "row_count": len(df),
    "column_importance": 0.8,
    "historical_failure_rate": 0.2
}

# %%
clean_df, decisions = run_neuro_symbolic_agent(df, data_context)

# %%
print("\n--- Rule Decisions ---")
for d in decisions:
    print(d)
# Out:
# --- Rule Decisions ---
# {'rule_id': 'R005', 'rule_name': 'Create total_amount', 'base_action': 'derive_column', 'confidence': 0.489, 'applied': True, 'reason': 'Applied by agent ranking'}
# {'rule_id': 'R002', 'rule_name': 'Drop high-null columns', 'base_action': 'drop_column', 'confidence': 0.486, 'applied': True, 'reason': 'Applied by agent ranking'}
# {'rule_id': 'R003', 'rule_name': 'Drop rows with critical nulls', 'base_action': 'drop_row', 'confidence': 0.485, 'applied': True, 'reason': 'Applied by agent ranking'}
# {'rule_id': 'R004', 'rule_name': 'Normalize dates', 'base_action': 'normalize_date', 'confidence': 0.48, 'applied': False, 'reason': 'Candidate rule'}
# {'rule_id': 'R001', 'rule_name': 'Enforce required columns', 'base_action': 'fail_pipeline', 'confidence': 0.477, 'applied': False, 'reason': 'Candidate rule'}

# %%
print("\n--- Dataset Info After Agent Execution ---")
print(clean_df.info())
# Out:
# --- Dataset Info After Agent Execution ---
# <class 'pandas.core.frame.DataFrame'>
# Index: 106 entries, 1 to 124
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  106 non-null    int64
#  1   age          106 non-null    object
#  2   salary       106 non-null    float64
#  3   signup_date  106 non-null    datetime64[ns]
#  4   active       106 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 5.0+ KB
# None

# %%
clean_df.to_csv("cleaned_dataset.csv", index=False)
